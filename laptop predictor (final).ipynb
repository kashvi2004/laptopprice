# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
 df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
# Convert columns to string type
df['Ram'] = df['Ram'].astype(str)
df['Weight'] = df['Weight'].astype(str)

# Remove units
df['Ram'] = df['Ram'].str.replace('GB', '')
df['Weight'] = df['Weight'].str.replace('kg', '')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram'] = df['Ram'].fillna(0).astype('int32')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), int32(1), object(8)
# memory usage: 107.0+ KB

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define custom styling parameters
sns.set(style="whitegrid")
palette = sns.color_palette("husl")

# Create the distribution plot with advanced styling
sns.distplot(df['Price'], hist=True, kde=True, 
             bins=30, color=palette[2], 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})

# Customize labels and titles
plt.xlabel('Price')
plt.ylabel('Density')
plt.title('Distribution of Laptop Prices')

# Display the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\2089297669.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'], hist=True, kde=True,

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
colors = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['Company'], y=df['Price'], palette=colors)

# Rotate x-axis labels vertically
plt.xticks(rotation='vertical')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\224837429.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Company'], y=df['Price'], palette=colors)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\224837429.py:8: UserWarning:
# The palette list has fewer values (10) than needed (19) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=df['Company'], y=df['Price'], palette=colors)

# %%
import matplotlib.pyplot as plt

# %%
# Define colors
colors = ['blue', 'green', 'red', 'orange', 'purple']

# Create the bar plot with specified colors
df['TypeName'].value_counts().plot(kind='bar', color=colors)

# Add labels and title
plt.xlabel('Type Name')
plt.ylabel('Count')
plt.title('Number of Laptops by Type Name')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
colors = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['TypeName'], y=df['Price'], palette=colors)

# Rotate x-axis labels vertically
plt.xticks(rotation='vertical')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\972032564.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['TypeName'], y=df['Price'], palette=colors)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\972032564.py:8: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.barplot(x=df['TypeName'], y=df['Price'], palette=colors)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define color for the distribution plot
color = 'skyblue'

# Create the distribution plot with the specified color
sns.distplot(df['Inches'], color=color)

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\3558717979.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'], color=color)

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches   ScreenResolution  \
# 896     Dell    Gaming    15.6  Full HD 1920x1080
# 890       HP  Notebook    14.0  Full HD 1920x1080
# 289   Lenovo  Notebook    15.6  Full HD 1920x1080
# 1152  Lenovo  Notebook    15.6  Full HD 1920x1080
# 31      Asus  Notebook    14.0           1366x768
#
#                               Cpu  Ram              Memory  \
# 896   Intel Core i7 7700HQ 2.8GHz    8             1TB HDD
# 890    Intel Core i5 7200U 2.5GHz    4           128GB SSD
# 289    Intel Core i7 7500U 2.7GHz    8             1TB HDD
# 1152   Intel Core i5 6200U 2.3GHz    8             1TB HDD
# 31    AMD E-Series E2-6110 1.5GHz    2  32GB Flash Storage
#
#                             Gpu       OpSys Weight       Price  Touchscreen
# 896   Nvidia GeForce GTX 1050Ti       Linux   2.62  49497.1200            0
# 890       Intel HD Graphics 620  Windows 10   1.95  67399.2000            0
# 289        Nvidia GeForce 940MX       No OS    2.2  35112.0528            0
# ...

# %%
# Define colors
colors = ['blue', 'orange']

# Create the bar plot with specified colors
df['Touchscreen'].value_counts().plot(kind='bar', color=colors)

# Add labels and title
plt.xlabel('Touchscreen')
plt.ylabel('Count')
plt.title('Number of Laptops by Touchscreen Availability')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
palette = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['Touchscreen'], y=df['Price'], palette=palette)

# Add labels and title
plt.xlabel('Touchscreen')
plt.ylabel('Price')
plt.title('Price vs Touchscreen')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\3150743811.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Touchscreen'], y=df['Price'], palette=palette)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\3150743811.py:8: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.barplot(x=df['Touchscreen'], y=df['Price'], palette=palette)

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define colors
colors = ['blue', 'orange']

# Create the bar plot with specified colors
df['Ips'].value_counts().plot(kind='bar', color=colors)

# Add labels and title
plt.xlabel('IPS')
plt.ylabel('Count')
plt.title('Number of Laptops by IPS Availability')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
palette = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['Ips'], y=df['Price'], palette=palette)

# Add labels and title
plt.xlabel('IPS')
plt.ylabel('Price')
plt.title('Price vs IPS')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\4053400706.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Ips'], y=df['Price'], palette=palette)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\4053400706.py:8: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.barplot(x=df['Ips'], y=df['Price'], palette=palette)

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches             ScreenResolution  \
# 1232    Dell     Notebook    15.6         Touchscreen 1366x768
# 1245    Asus       Gaming    15.6  IPS Panel Full HD 1920x1080
# 699       HP     Notebook    15.6  IPS Panel Full HD 1920x1080
# 460     Acer     Notebook    15.6            Full HD 1920x1080
# 1143      HP  Workstation    15.6  IPS Panel Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 1232   Intel Core i3 7100U 2.4GHz    8               1TB HDD
# 1245  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 699    Intel Core i7 7500U 2.7GHz    4             500GB HDD
# 460      Intel Core i3 6006U 2GHz    4               1TB HDD
# 1143  Intel Core i7 6700HQ 2.6GHz    8             256GB SSD
#
#                              Gpu       OpSys Weight        Price  Touchscreen  \
# 1232       Intel HD Graphics 620  Windows 10    2.3   24988.8528            1
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float64(2), int32(3), int64(2), object(8)
# ...

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation = numeric_df.corr()['Price']

# %%
print(correlation)
# Out:
# Inches         0.068197
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
ppi_price_correlation = df['ppi'].corr(df['Price'])

print("Correlation between 'ppi' and 'Price':", ppi_price_correlation)
# Out:
# Correlation between 'ppi' and 'Price': 0.47348730766086017

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS   1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS   1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS   1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price  Touchscreen  Ips  X_res  Y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu brand
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
palette = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.countplot(data=df, x='Cpu brand', palette=palette)

# Add labels and title
plt.xlabel('CPU Brand')
plt.ylabel('Count')
plt.title('Number of Laptops by CPU Brand')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\1981126769.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Cpu brand', palette=palette)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\1981126769.py:8: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.countplot(data=df, x='Cpu brand', palette=palette)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
palette = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['Cpu brand'], y=df['Price'], palette=palette)

# Rotate x-axis labels vertically
plt.xticks(rotation='vertical')

# Add labels and title
plt.xlabel('CPU Brand')
plt.ylabel('Price')
plt.title('Price vs CPU Brand')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\240843266.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Cpu brand'], y=df['Price'], palette=palette)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\240843266.py:8: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.barplot(x=df['Cpu brand'], y=df['Price'], palette=palette)

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS   1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS   1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS   1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS   1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS   1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define colors
colors = ['blue', 'orange', 'green', 'red', 'purple', 'yellow', 'pink', 'brown']

# Create the bar plot with specified colors
df['Ram'].value_counts().plot(kind='bar', color=colors)

# Add labels and title
plt.xlabel('RAM (GB)')
plt.ylabel('Count')
plt.title('Number of Laptops by RAM')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
palette = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['Ram'], y=df['Price'], palette=palette)

# Rotate x-axis labels vertically
plt.xticks(rotation='vertical')

# Add labels and title
plt.xlabel('RAM (GB)')
plt.ylabel('Price')
plt.title('Price vs RAM')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\1123390542.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Ram'], y=df['Price'], palette=palette)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\1123390542.py:8: UserWarning: The palette list has more values (10) than needed (9), which may not be intended.
#   sns.barplot(x=df['Ram'], y=df['Price'], palette=palette)

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# Preprocess 'Memory' column
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Split 'Memory' column into two parts
new = df["Memory"].str.split("+", n=1, expand=True)
df["first"] = new[0].str.extract(r'(\d+)').astype(float)
df["second"] = new[1].str.extract(r'(\d+)').astype(float)

# Create binary columns indicating the presence of different types of storage
df["Layer1HDD"] = df["Memory"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["Memory"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["Memory"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["Memory"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Create binary columns for the second part of memory
df["Layer2HDD"] = df["second"].fillna("").apply(lambda x: 1 if "HDD" in str(x) else 0)
df["Layer2SSD"] = df["second"].fillna("").apply(lambda x: 1 if "SSD" in str(x) else 0)
df["Layer2Hybrid"] = df["second"].fillna("").apply(lambda x: 1 if "Hybrid" in str(x) else 0)
df["Layer2Flash_Storage"] = df["second"].fillna("").apply(lambda x: 1 if "Flash Storage" in str(x) else 0)

# Extract numeric values from 'first' and 'second' columns
df["first"] = df["first"].fillna(0)
df["second"] = df["second"].fillna(0)

# Calculate the total storage capacity for each type
df["HDD"] = df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"]
df["SSD"] = df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"]
df["Hybrid"] = df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"]
df["Flash_Storage"] = df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"]

# Drop intermediate columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
                 'Layer2Flash_Storage'], inplace=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 1153    Dell              Gaming    8             1000 HDD
# 885       HP  2 in 1 Convertible    4              256 SSD
# 738      MSI              Gaming   16  256 SSD +  1000 HDD
# 589     Asus              Gaming    8  128 SSD +  1000 HDD
# 41      Dell              Gaming   16  256 SSD +  1000 HDD
#
#                             Gpu       OpSys Weight        Price  Touchscreen  \
# 1153  Nvidia GeForce GTX 1050Ti  Windows 10   2.62   63882.7200            0
# 885       Intel HD Graphics 620  Windows 10   1.28   95850.7200            1
# 738     Nvidia GeForce GTX 1060  Windows 10    1.8  111593.8944            0
# 589     Nvidia GeForce GTX 1060  Windows 10   2.73   94305.6000            0
# 41      Nvidia GeForce GTX 1060  Windows 10   2.65   79866.7200            0
#
#       Ips         ppi      Cpu brand     HDD    SSD  Hybrid  Flash_Storage
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
# Drop non-numeric columns
df_numeric = df.select_dtypes(include=['number'])

# Compute correlation
correlation = df_numeric.corr()['Price']
print(correlation)
# Out:
# Ram              0.743007
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.303621
# SSD              0.676202
# Hybrid          -0.020186
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS   1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS   1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS   1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS   1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD    SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5  0.0  128.0
# 1   47895.5232            0    0  127.677940  Intel Core i5  0.0    0.0
# 2   30636.0000            0    0  141.211998  Intel Core i5  0.0  256.0
# 3  135195.3360            0    1  220.534624  Intel Core i7  0.0  512.0
# 4   96095.8080            0    1  226.983005  Intel Core i5  0.0  256.0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS   1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS   1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS   1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS   1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS   1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD    SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  0.0  128.0
# 1   47895.5232            0    0  127.677940  Intel Core i5  0.0    0.0
# 2   30636.0000            0    0  141.211998  Intel Core i5  0.0  256.0
# 3  135195.3360            0    1  220.534624  Intel Core i7  0.0  512.0
# 4   96095.8080            0    1  226.983005  Intel Core i5  0.0  256.0
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette
palette = sns.color_palette("pastel")

# Create the bar plot with specified colors
sns.barplot(x=df['Gpu brand'], y=df['Price'], palette=palette)

# Rotate x-axis labels vertically
plt.xticks(rotation='vertical')

# Add labels and title
plt.xlabel('GPU Brand')
plt.ylabel('Price')
plt.title('Price vs GPU Brand')

# Show the plot
plt.show()
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\3879218154.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Gpu brand'], y=df['Price'], palette=palette)
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\3879218154.py:8: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.barplot(x=df['Gpu brand'], y=df['Price'], palette=palette)

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS   1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS   1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS   1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS   1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS   1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD    SSD Gpu brand
# 0  226.983005  Intel Core i5  0.0  128.0     Intel
# 1  127.677940  Intel Core i5  0.0    0.0     Intel
# 2  141.211998  Intel Core i5  0.0  256.0     Intel
# 3  220.534624  Intel Core i7  0.0  512.0       AMD
# 4  226.983005  Intel Core i5  0.0  256.0     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS   1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS   1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS   1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS   1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS   1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD    SSD Gpu brand                  os
# 0  226.983005  Intel Core i5  0.0  128.0     Intel                 Mac
# 1  127.677940  Intel Core i5  0.0    0.0     Intel                 Mac
# 2  141.211998  Intel Core i5  0.0  256.0     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7  0.0  512.0       AMD                 Mac
# 4  226.983005  Intel Core i5  0.0  256.0     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\348573483.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
# Drop non-numeric columns
df_numeric = df.select_dtypes(include=['number'])

# Compute correlation
correlation = df_numeric.corr()['Price']
print(correlation)
# Out:
# Ram            0.742905
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.304067
# SSD            0.676066
# Name: Price, dtype: float64

# %%
# Assuming df is your DataFrame containing your data
# Convert non-numeric columns to numeric format if possible
df_numeric = df.apply(pd.to_numeric, errors='coerce')

# Now calculate the correlation matrix and create the heatmap
sns.heatmap(df_numeric.corr())
# Out:
# <Axes: >

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\Madhav\AppData\Local\Temp\ipykernel_18396\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8   1.37            0    1  226.983005
# 1      Apple           Ultrabook    8   1.34            0    0  127.677940
# 2         HP            Notebook    8   1.86            0    0  141.211998
# 3      Apple           Ultrabook   16   1.83            0    1  220.534624
# 4      Apple           Ultrabook    8   1.37            0    1  226.983005
# ...      ...                 ...  ...    ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.8            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.3            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.5            0    0  111.935204
# 1301      HP            Notebook    6   2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.2            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.0            0    0  100.454670
# 1141      MSI              Gaming    8    2.4            0    0  141.211998
# 1049     Asus             Netbook    4    1.2            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4   2.08            1    1  141.211998
# 878      Dell            Notebook    4   2.18            0    0  141.211998
# ...       ...                 ...  ...    ...          ...  ...         ...
# 466      Acer            Notebook    4    2.2            0    0  100.454670
# 299      Asus           Ultrabook   16   1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.2            0    0  100.454670
# 527    Lenovo            Notebook    8    2.2            0    0  100.454670
# 1193    Apple           Ultrabook    8  0.920            0    1  226.415547
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
pip install scipy
# Out:
# ...
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
                            # Linear regression

# Define the column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the linear regression model
step2 = LinearRegression()

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Calculate and print evaluation metrics
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8100463214885838
# MAE: 0.20855962464813393

# %%
                                # Lasso regression

# Define the column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the Lasso regression model
step2 = Lasso(alpha=0.001)

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Calculate and print evaluation metrics
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8098864171158076
# MAE: 0.2096055673420472

# %%
                                    #KNN

# Define the column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the KNeighborsRegressor model
step2 = KNeighborsRegressor(n_neighbors=3)

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Calculate and print evaluation metrics
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.811040697718463
# MAE: 0.19000681244867934

# %% [markdown]
# DECCISION TREEES

# %%
# Define the column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the DecisionTreeRegressor model
step2 = DecisionTreeRegressor(max_depth=8)

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Calculate and print evaluation metrics
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8481746929145496
# MAE: 0.18180902666770196

# %%
                                            #SVM

# Define the column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the SVR model
step2 = SVR(kernel='rbf', C=10000, epsilon=0.1)

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Calculate and print evaluation metrics
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8306994670901435
# MAE: 0.19454322713497518

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram Weight        Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8   1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8   1.34   47895.5232            0    0
# 2         HP            Notebook    8   1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16   1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8   1.37   96095.8080            0    1
# ...      ...                 ...  ...    ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.8   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.3   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.5   12201.1200            0    0
# 1301      HP            Notebook    6   2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.2   19660.3200            0    0
#
# ...

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.2
